# %% [markdown]
# The Lorenz system is a system of three ODEs having chaotic solutions (butterfly effect).
#
# $$\begin{split} \dot{x} & = \sigma (y - x) \\
# \dot{y} & = x (\rho - z) - y \\
# \dot{z} & = xy - \beta z
# \end{split}$$
#
# Reference: https://en.wikipedia.org/wiki/Lorenz_system

# %%
from lmmNet import lmmNet
import numpy as np
from scipy.integrate import odeint

# %%
def f(x,t):
    """
    The system of ODEs for the nonlinear Lorenz system with default parameters
    
    Arguments:
    x --  a list with three elements corresponding to the three variables
    t -- time
    
    Return:
    A numpy array containing the derivatives
    """
    
    sigma = 10.0
    beta = 8.0/3.0
    rho = 28.0

    r1 = sigma * (x[1] - x[0])
    r2 = x[0] * (rho - x[2]) - x[1]
    r3 = x[0] * x[1] - beta * x[2]

    return np.array([r1, r2, r3])

# %%
# initial condition
x0 = np.array([-8.0, 7.0, 27])

t0 = 0 # start time
T = 25 # end time
h = 0.01 # step size

# generate data
time_points = np.arange(t0, T, h)
lorenz_data = odeint(f, x0, time_points)

# %%
# add Gaussian noise scaled by standard deviation, for every one of the three dimensions
noise_strength = 0.00
lorenz_data += noise_strength * lorenz_data.std(0) * np.random.randn(lorenz_data.shape[0], lorenz_data.shape[1])

lorenz_data = np.reshape(lorenz_data, (1,lorenz_data.shape[0], lorenz_data.shape[1]))

# %%
hidden_layer_units = 256 # number of units for the hidden layer
M = 1 # number of steps
scheme = 'AM' # LMM scheme
model = lmmNet(h, lorenz_data, M, scheme, hidden_layer_units)

N_Iter = 10000
model.train(N_Iter)
# Out:
# WARNING:tensorflow:Layer dense_model is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# Epoch: 0, Loss: 1.245e+00, Time: 0.18
# Epoch: 100, Loss: 1.029e+00, Time: 7.31
# Epoch: 200, Loss: 8.478e-01, Time: 14.45
# Epoch: 300, Loss: 7.074e-01, Time: 22.25
# Epoch: 400, Loss: 6.008e-01, Time: 30.91
# Epoch: 500, Loss: 5.131e-01, Time: 38.26
# Epoch: 600, Loss: 4.428e-01, Time: 45.21
# Epoch: 700, Loss: 3.860e-01, Time: 54.18
# Epoch: 800, Loss: 3.384e-01, Time: 63.99
# Epoch: 900, Loss: 2.983e-01, Time: 71.88
# Epoch: 1000, Loss: 2.640e-01, Time: 80.25
# Epoch: 1100, Loss: 2.346e-01, Time: 88.76
# Epoch: 1200, Loss: 2.094e-01, Time: 96.53
# Epoch: 1300, Loss: 1.878e-01, Time: 103.97
# Epoch: 1400, Loss: 1.690e-01, Time: 111.69
# Epoch: 1500, Loss: 1.527e-01, Time: 120.42
# Epoch: 1600, Loss: 1.384e-01, Time: 128.59
# Epoch: 1700, Loss: 1.257e-01, Time: 136.40
# Epoch: 1800, Loss: 1.144e-01, Time: 143.59
# Epoch: 1900, Loss: 1.043e-01, Time: 150.84
# Epoch: 2000, Loss: 9.531e-02, Time: 158.44
# Epoch: 2100, Loss: 8.716e-02, Time: 166.52
# Epoch: 2200, Loss: 7.972e-02, Time: 174.10
# Epoch: 2300, Loss: 7.298e-02, Time: 181.28
# Epoch: 2400, Loss: 6.684e-02, Time: 189.10
# Epoch: 2500, Loss: 6.118e-02, Time: 196.23
# Epoch: 2600, Loss: 5.595e-02, Time: 203.18
# Epoch: 2700, Loss: 5.109e-02, Time: 210.84
# Epoch: 2800, Loss: 4.663e-02, Time: 218.72
# Epoch: 2900, Loss: 4.256e-02, Time: 226.47
# Epoch: 3000, Loss: 3.885e-02, Time: 236.98
# Epoch: 3100, Loss: 3.535e-02, Time: 244.82
# Epoch: 3200, Loss: 3.202e-02, Time: 252.80
# Epoch: 3300, Loss: 2.914e-02, Time: 261.42
# Epoch: 3400, Loss: 2.656e-02, Time: 269.72
# Epoch: 3500, Loss: 2.424e-02, Time: 277.00
# Epoch: 3600, Loss: 2.216e-02, Time: 284.43
# Epoch: 3700, Loss: 2.024e-02, Time: 291.95
# Epoch: 3800, Loss: 1.854e-02, Time: 299.36
# Epoch: 3900, Loss: 1.699e-02, Time: 306.76
# Epoch: 4000, Loss: 1.559e-02, Time: 314.21
# Epoch: 4100, Loss: 1.431e-02, Time: 322.58
# Epoch: 4200, Loss: 1.315e-02, Time: 330.81
# Epoch: 4300, Loss: 1.205e-02, Time: 338.92
# Epoch: 4400, Loss: 1.104e-02, Time: 346.88
# Epoch: 4500, Loss: 1.013e-02, Time: 354.92
# Epoch: 4600, Loss: 9.297e-03, Time: 363.05
# Epoch: 4700, Loss: 8.498e-03, Time: 371.10
# Epoch: 4800, Loss: 7.806e-03, Time: 381.40
# Epoch: 4900, Loss: 7.181e-03, Time: 391.14
# Epoch: 5000, Loss: 6.608e-03, Time: 399.48
# Epoch: 5100, Loss: 6.087e-03, Time: 407.60
# Epoch: 5200, Loss: 5.611e-03, Time: 416.44
# Epoch: 5300, Loss: 5.174e-03, Time: 424.64
# Epoch: 5400, Loss: 4.774e-03, Time: 432.95
# Epoch: 5500, Loss: 4.406e-03, Time: 440.90
# Epoch: 5600, Loss: 4.068e-03, Time: 448.87
# Epoch: 5700, Loss: 3.756e-03, Time: 456.95
# Epoch: 5800, Loss: 3.471e-03, Time: 465.26
# Epoch: 5900, Loss: 3.204e-03, Time: 473.28
# Epoch: 6000, Loss: 2.959e-03, Time: 481.49
# Epoch: 6100, Loss: 2.733e-03, Time: 489.95
# Epoch: 6200, Loss: 2.500e-03, Time: 497.96
# Epoch: 6300, Loss: 2.293e-03, Time: 506.05
# Epoch: 6400, Loss: 2.113e-03, Time: 514.01
# Epoch: 6500, Loss: 1.948e-03, Time: 522.02
# Epoch: 6600, Loss: 1.788e-03, Time: 529.96
# Epoch: 6700, Loss: 1.643e-03, Time: 537.95
# Epoch: 6800, Loss: 1.507e-03, Time: 545.86
# Epoch: 6900, Loss: 1.388e-03, Time: 553.91
# Epoch: 7000, Loss: 1.279e-03, Time: 561.90
# Epoch: 7100, Loss: 1.179e-03, Time: 569.83
# Epoch: 7200, Loss: 1.087e-03, Time: 577.76
# Epoch: 7300, Loss: 1.002e-03, Time: 588.73
# Epoch: 7400, Loss: 9.246e-04, Time: 601.39
# Epoch: 7500, Loss: 8.533e-04, Time: 608.78
# Epoch: 7600, Loss: 7.891e-04, Time: 615.59
# Epoch: 7700, Loss: 7.259e-04, Time: 622.12
# Epoch: 7800, Loss: 6.715e-04, Time: 637.24
# Epoch: 7900, Loss: 6.188e-04, Time: 650.59
# Epoch: 8000, Loss: 5.715e-04, Time: 659.71
# Epoch: 8100, Loss: 5.272e-04, Time: 669.75
# Epoch: 8200, Loss: 4.866e-04, Time: 682.66
# Epoch: 8300, Loss: 4.505e-04, Time: 691.23
# Epoch: 8400, Loss: 4.162e-04, Time: 697.68
# Epoch: 8500, Loss: 3.841e-04, Time: 705.28
# Epoch: 8600, Loss: 3.577e-04, Time: 712.32
# Epoch: 8700, Loss: 3.287e-04, Time: 719.41
# Epoch: 8800, Loss: 3.051e-04, Time: 725.84
# Epoch: 8900, Loss: 2.843e-04, Time: 734.62
# Epoch: 9000, Loss: 2.618e-04, Time: 741.22
# Epoch: 9100, Loss: 2.421e-04, Time: 747.84
# Epoch: 9200, Loss: 2.249e-04, Time: 756.50
# Epoch: 9300, Loss: 2.106e-04, Time: 763.75
# Epoch: 9400, Loss: 1.935e-04, Time: 771.85
# Epoch: 9500, Loss: 1.801e-04, Time: 778.96
# Epoch: 9600, Loss: 1.694e-04, Time: 786.36
# Epoch: 9700, Loss: 1.591e-04, Time: 798.62
# Epoch: 9800, Loss: 1.503e-04, Time: 807.65
# Epoch: 9900, Loss: 1.376e-04, Time: 817.09

# %%
def ml_f(x, model):
    """
    Define the derivatives learned by ML
    I think this is the best implementation, more robust than flatten()
    """
    return np.ravel(model.predict(x.reshape(1,-1)))
