# %% [markdown]
# First of all, we want to see how the system looks like when we add Gaussian noise to the derivatives. We also compare this to the case when the Gaussian noise is added to the integrated dynamics.
#
# First I add the noise to the integrated dynamics:
# $$ x(t) = x_0 + \int f(x(t)) /d,t + \epsilon$$

# %%
import sys
sys.path.append("./source")
from train import *
from predict import *
from model import *
import NovakTyson
import pickle
import matplotlib.pyplot as plt

# %%
# simulate data with varying amount of noise
time_points, novak_data1 = NovakTyson.simulate_custom(noise=0.01, tlast=1500)
_, novak_data2 = NovakTyson.simulate_custom(noise=0.02, tlast=1500)
_, novak_data3 = NovakTyson.simulate_custom(noise=0.1, tlast=1500)
_, novak_data4 = NovakTyson.simulate_custom(noise=0.0, tlast=1500)

# %%
# 0.01 Gaussian noise
plt.clf()
plt.figure(figsize=(20, 10))
for species in range(7):
    plt.subplot(7, 1, species + 1)
    plt.plot(time_points, novak_data1[0, :, species])

# %%
plt.clf()
plt.figure(figsize=(20, 10))
for species in range(7):
    plt.subplot(7, 1, species + 1)
    plt.plot(time_points, novak_data2[0, :, species])

# %%
plt.clf()
plt.figure(figsize=(20, 10))
for species in range(7):
    plt.subplot(7, 1, species + 1)
    plt.plot(time_points, novak_data3[0, :, species])

# %% [markdown]
# Now let's see what happen if we use a stochastic ODE with Gaussian noise. Here, the expected slope is not the same as the realized slope.
# $$ f(x) = g(x) + \epsilon $$
# Gaussian white noise.

# %%
import pickle

# load data
with open('./data/stochastic_cellcycle_01.pkl', 'rb') as file:
    data_dict = pickle.load(file)
    
data_array = data_dict['data']
time_points = data_dict['t']
print(data_array)
# Out:
# tf.Tensor(
# [[[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  0.0000000e+00
#     1.0000000e+00  1.0000000e+00]
#   [ 8.3260275e-05  1.7275298e-06 -7.2885479e-07 ... -6.7136494e-07
#     9.9998766e-01  9.9999458e-01]
#   [ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  0.0000000e+00
#     0.0000000e+00  0.0000000e+00]
#   ...
#   [ 3.6350711e-27  0.0000000e+00  0.0000000e+00 ...  0.0000000e+00
#     0.0000000e+00  3.9904688e-08]
#   [ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  0.0000000e+00
#     0.0000000e+00  0.0000000e+00]
#   [ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  0.0000000e+00
#     0.0000000e+00  0.0000000e+00]]], shape=(1, 7500, 7), dtype=float32)

# %%
plt.clf()
plt.figure(figsize=(20, 10))
for species in range(7):
    plt.subplot(4, 2, species + 1)
    plt.yscale('log')
    plt.plot(time_points, data_array[0, :, species])

# %%
import pickle

# load data
with open('./data/stochastic_cellcycle_t02_n01.pkl', 'rb') as file:
    data_dict = pickle.load(file)
    
data_array = data_dict['data']
time_points = data_dict['t']
print(data_array)
# Out:
# tf.Tensor(
# [[[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  0.0000000e+00
#     1.0000000e+00  1.0000000e+00]
#   [ 1.1423149e-04  6.6015537e-07 -1.3807249e-06 ... -5.3604390e-07
#     9.9998271e-01  9.9999136e-01]
#   [ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  0.0000000e+00
#     0.0000000e+00  0.0000000e+00]
#   ...
#   [ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  0.0000000e+00
#     0.0000000e+00  0.0000000e+00]
#   [ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  0.0000000e+00
#     0.0000000e+00  0.0000000e+00]
#   [ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  0.0000000e+00
#     0.0000000e+00  0.0000000e+00]]], shape=(1, 75000, 7), dtype=float32)

# %%
plt.clf()
plt.figure(figsize=(20, 10))
for species in range(7):
    plt.subplot(4, 2, species + 1)
    #plt.yscale('log')
    plt.plot(time_points, data_array[0, :, species])

# %%
plt.clf()
plt.figure(figsize=(20, 10))
for species in range(7):
    plt.subplot(4, 2, species + 1)
    plt.yscale('log')
    plt.plot(time_points, data_array[0, :, species])

# %%
plt.clf()
plt.figure(figsize=(20, 10))
for species in range(7):
    plt.subplot(4, 2, species + 1)
    plt.yscale('log')
    plt.plot(time_points, data_array[0, :, species], 'r.')

# %%
import pickle

# load data
with open('./data/stochastic_cellcycle_t2_n-10.pkl', 'rb') as file:
    data_dict = pickle.load(file)
    
data_array = data_dict['data']
time_points = data_dict['t']
print(data_array)
# Out:
# tf.Tensor(
# [[[0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#    1.00000000e+00 1.00000000e+00]
#   [1.85744539e-01 8.76543764e-03 5.95127000e-04 ... 6.00924113e-06
#    9.70309615e-01 9.93760645e-01]
#   [3.45694214e-01 3.08249891e-02 4.25871788e-03 ... 4.34299764e-05
#    9.40682590e-01 9.91450369e-01]
#   ...
#   [2.00903773e+00 4.07018566e+00 5.96064329e+00 ... 3.64921987e-01
#    1.12480605e-02 1.23365797e-01]
#   [2.01412249e+00 4.11214304e+00 6.02913094e+00 ... 3.65922570e-01
#    1.14886919e-02 1.20829038e-01]
#   [2.01918674e+00 4.15462303e+00 6.09780741e+00 ... 3.66971374e-01
#    1.17375115e-02 1.18350469e-01]]], shape=(1, 7500, 7), dtype=float32)

# %%
plt.clf()
plt.figure(figsize=(20, 10))
for species in range(7):
    plt.subplot(4, 2, species + 1)
    #plt.yscale('log')
    plt.plot(time_points, data_array[0, :, species], 'r.')

# %%
import pickle

# load data
with open('./data/stochastic_cellcycle_t2_n-8.pkl', 'rb') as file:
    data_dict = pickle.load(file)
    
data_array = data_dict['data']
time_points = data_dict['t']
print(data_array)
# Out:
# tf.Tensor(
# [[[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#    1.0000000e+00 1.0000000e+00]
#   [1.8574454e-01 8.7654386e-03 5.9512671e-04 ... 6.0098309e-06
#    9.7030962e-01 9.9376065e-01]
#   [3.4569421e-01 3.0824991e-02 4.2587174e-03 ... 4.3430628e-05
#    9.4068259e-01 9.9145037e-01]
#   ...
#   [2.0090322e+00 4.0701413e+00 5.9605699e+00 ... 3.6492112e-01
#    1.1247710e-02 1.2336857e-01]
#   [2.0141170e+00 4.1120982e+00 6.0290570e+00 ... 3.6592165e-01
#    1.1488391e-02 1.2083174e-01]
#   [2.0191815e+00 4.1545777e+00 6.0977330e+00 ... 3.6697039e-01
#    1.1737220e-02 1.1835312e-01]]], shape=(1, 7500, 7), dtype=float32)

# %%
plt.clf()
plt.figure(figsize=(20, 10))
for species in range(7):
    plt.subplot(4, 2, species + 1)
    #plt.yscale('log')
    plt.plot(time_points, data_array[0, :, species], 'r.')

# %% [markdown]
# The tiny noise here is below the threshold for the numerical 'noise'. That's why it has no effects on the integration even though it uses LSODA.

# %%
import pickle

# load data
with open('./data/stochastic_cellcycle_t2_n-5.pkl', 'rb') as file:
    data_dict = pickle.load(file)
    
data_array = data_dict['data']
time_points = data_dict['t']
print(data_array)
# Out:
# tf.Tensor(
# [[[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  0.0000000e+00
#     1.0000000e+00  1.0000000e+00]
#   [ 4.8208176e-03  1.3852501e-06 -1.0480713e-07 ...  6.1318232e-08
#     9.9928319e-01  9.9969620e-01]
#   [ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  0.0000000e+00
#     0.0000000e+00  0.0000000e+00]
#   ...
#   [ 3.6350711e-27  0.0000000e+00  0.0000000e+00 ...  0.0000000e+00
#     0.0000000e+00  3.9904688e-08]
#   [ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  0.0000000e+00
#     0.0000000e+00  0.0000000e+00]
#   [ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  0.0000000e+00
#     0.0000000e+00  0.0000000e+00]]], shape=(1, 7500, 7), dtype=float32)

# %%
plt.clf()
plt.figure(figsize=(20, 10))
for species in range(7):
    plt.subplot(4, 2, species + 1)
    #plt.yscale('log')
    plt.plot(time_points, data_array[0, :, species], 'r.')

# %%
import pickle

# load data
with open('./data/stochastic_cellcycle_t2_n-6.pkl', 'rb') as file:
    data_dict = pickle.load(file)
    
data_array = data_dict['data']
time_points = data_dict['t']
print(data_array)
# Out:
# tf.Tensor(
# [[[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  0.0000000e+00
#     1.0000000e+00  1.0000000e+00]
#   [ 4.6744510e-03  9.6875647e-07  4.6975481e-07 ... -1.0404010e-07
#     9.9930441e-01  9.9970466e-01]
#   [ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  0.0000000e+00
#     0.0000000e+00  0.0000000e+00]
#   ...
#   [ 3.6350711e-27  0.0000000e+00  0.0000000e+00 ...  0.0000000e+00
#     0.0000000e+00  3.9904688e-08]
#   [ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  0.0000000e+00
#     0.0000000e+00  0.0000000e+00]
#   [ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  0.0000000e+00
#     0.0000000e+00  0.0000000e+00]]], shape=(1, 7500, 7), dtype=float32)

# %%
plt.clf()
plt.figure(figsize=(20, 10))
for species in range(7):
    plt.subplot(4, 2, species + 1)
    #plt.yscale('log')
    plt.plot(time_points, data_array[0, :, species], 'r.')

# %%
import pickle

# load data
with open('./data/stochastic_cellcycle_t2_n-7.pkl', 'rb') as file:
    data_dict = pickle.load(file)
    
data_array = data_dict['data']
time_points = data_dict['t']
print(data_array)
# Out:
# tf.Tensor(
# [[[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#    1.0000000e+00 1.0000000e+00]
#   [1.8574454e-01 8.7654423e-03 5.9512944e-04 ... 6.0096695e-06
#    9.7030962e-01 9.9376059e-01]
#   [3.4569421e-01 3.0824991e-02 4.2587216e-03 ... 4.3427925e-05
#    9.4068259e-01 9.9145031e-01]
#   ...
#   [3.6350711e-27 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#    0.0000000e+00 3.9904688e-08]
#   [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#    0.0000000e+00 0.0000000e+00]
#   [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#    0.0000000e+00 0.0000000e+00]]], shape=(1, 7500, 7), dtype=float32)

# %%
plt.clf()
plt.figure(figsize=(20, 10))
for species in range(7):
    plt.subplot(4, 2, species + 1)
    #plt.yscale('log')
    plt.plot(time_points, data_array[0, :, species], 'r.')

# %%
from stochastic_ode import *
dat = []

for noise in [2 * 10**-7, 6 * 10**-7, 9 * 10**-7]:
    time_points, novak_data = simulate_stochastic(tlast=1500, noise=noise, step_size=0.2)
    dat.append(novak_data)
# Out:
# /Users/kevinsiswandi/opt/anaconda3/lib/python3.7/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)

# %%
# step 2e-7
plt.clf()
plt.figure(figsize=(20, 10))
for species in range(7):
    plt.subplot(4, 2, species + 1)
    #plt.yscale('log')
    plt.plot(time_points, dat[0][0, :, species], 'r.')

# %%
# step 6e-7
plt.clf()
plt.figure(figsize=(20, 10))
for species in range(7):
    plt.subplot(4, 2, species + 1)
    #plt.yscale('log')
    plt.plot(time_points, dat[1][0, :, species], 'r.')

# %%
# step 9e-7
plt.clf()
plt.figure(figsize=(20, 10))
for species in range(7):
    plt.subplot(4, 2, species + 1)
    #plt.yscale('log')
    plt.plot(time_points, dat[2][0, :, species], 'r.')

# %%
from stochastic_ode import *
dat = []

for noise in [2 * 10**-8, 6 * 10**-8, 9 * 10**-8]:
    time_points, novak_data = simulate_stochastic(tlast=1500, noise=noise, step_size=0.2)
    dat.append(novak_data)

# %%
# step 9e-7
plt.clf()
plt.figure(figsize=(20, 10))
for species in range(7):
    plt.subplot(4, 2, species + 1)
    #plt.yscale('log')
    plt.plot(time_points, dat[1][0, :, species], 'r.')

# %%
# try solving the Ornstein-Uhlenbeck process

import numpy as np
import matplotlib.pyplot as plt

t_0 = 0      # define model parameters
t_end = 2
length = 1000
theta  = 1.1
mu     = 0.8
sigma  = 0.3

t = np.linspace(t_0,t_end,length)  # define time axis
dt = np.mean(np.diff(t))

y = np.zeros(length)
y0 = np.random.normal(loc=0.0,scale=1.0)  # initial condition

drift = lambda y,t: theta*(mu-y)      # define drift term
diffusion = lambda y,t: sigma# define diffusion term
noise = np.random.normal(loc=0.0,scale=1.0,size=length)*np.sqrt(dt) #define noise process

# solve SDE using the Euler-Maruyama scheme
for i in range(1,length):
    y[i] = y[i-1] + drift(y[i-1],i*dt)*dt + diffusion(y[i-1],i*dt)*noise[i]

plt.plot(t,y)
plt.show()

# %%
# try solving the Ornstein-Uhlenbeck process

for j in range(10):
    t_0 = 0      # define model parameters
    t_end = 2
    length = 1000
    theta  = 1.1
    mu     = 0.8
    sigma  = 0.3

    t = np.linspace(t_0,t_end,length)  # define time axis
    dt = np.mean(np.diff(t))

    y = np.zeros(length)
    y0 = np.random.normal(loc=0.0,scale=1.0)  # initial condition

    drift = lambda y,t: theta*(mu-y)      # define drift term
    diffusion = lambda y,t: sigma# define diffusion term
    noise = np.random.normal(loc=0.0,scale=1.0,size=length)*np.sqrt(dt) #define noise process

    # solve SDE using the Euler-Maruyama scheme
    for i in range(1,length):
        y[i] = y[i-1] + drift(y[i-1],i*dt)*dt + diffusion(y[i-1],i*dt)*noise[i]

    plt.plot(t,y)

plt.show()

# %%
import sys
sys.path.append("./source")

from stochastic_ode import *
import matplotlib.pyplot as plt

time_points, data = simulate_simple(ns = 10**-7)
plt.plot(time_points, data[0])

# %%
time_points, data = simulate_simple(ns = 10**-4)
plt.plot(time_points, data[0], 'r.')
plt.yscale('log')

# %%
time_points, data = simulate_simple(ns = 10**-4)
plt.plot(time_points, data[0], 'r.')
#plt.yscale('log')

# %%
for i in range(10):
    time_points, data = simulate_simple(ns = 10**-4)
    plt.plot(time_points, data[0])
plt.show()
# Out:
# /Users/kevinsiswandi/opt/anaconda3/lib/python3.7/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# /Users/kevinsiswandi/opt/anaconda3/lib/python3.7/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# /Users/kevinsiswandi/opt/anaconda3/lib/python3.7/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# ...

# %%
time_points, data = simulate_simple(ns = 10**-3)
plt.plot(time_points, data[0])
plt.yscale('log')
# Out:
# /Users/kevinsiswandi/opt/anaconda3/lib/python3.7/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# /Users/kevinsiswandi/opt/anaconda3/lib/python3.7/site-packages/numpy/ma/core.py:6717: RuntimeWarning: overflow encountered in power
#   result = np.where(m, fa, umath.power(fa, fb)).view(basetype)

# %%
time_points, data = simulate_simple(ns = 10**-5)
plt.plot(time_points, data[0])
#plt.yscale('log')

# %%
for i in range(10):
    time_points, data = simulate_simple(ns = 10**-3)
    plt.plot(time_points, data[0])
    plt.yscale('log')
plt.show()
# Out:
# /Users/kevinsiswandi/opt/anaconda3/lib/python3.7/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# /Users/kevinsiswandi/opt/anaconda3/lib/python3.7/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# /Users/kevinsiswandi/opt/anaconda3/lib/python3.7/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# ...

# %%
for i in range(10):
    time_points, data = simulate_simple(ns = 10**-4)
    plt.plot(time_points, data[0])
    plt.yscale('log')
plt.show()
# Out:
# /Users/kevinsiswandi/opt/anaconda3/lib/python3.7/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# /Users/kevinsiswandi/opt/anaconda3/lib/python3.7/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# /Users/kevinsiswandi/opt/anaconda3/lib/python3.7/site-packages/matplotlib/ticker.py:2352: RuntimeWarning: overflow encountered in power
#   ticklocs = b ** decades
# /Users/kevinsiswandi/opt/anaconda3/lib/python3.7/site-packages/matplotlib/ticker.py:2200: RuntimeWarning: invalid value encountered in double_scalars
#   return abs(x - np.round(x)) < 1e-10
# ...

# %%
for i in range(10):
    time_points, data = simulate_simple(ns = 10**-5)
    plt.plot(time_points, data[0])
    plt.yscale('log')
plt.show()

# %%
# try solving the linear equation

for j in range(10):
    t_0 = 0      # define model parameters
    t_end = 2
    length = 1000
    theta  = 1.1
    mu     = 0.8
    sigma  = 0.3

    t = np.linspace(t_0,t_end,length)  # define time axis
    dt = np.mean(np.diff(t))

    y = np.zeros(length)
    y0 = np.random.normal(loc=0.0,scale=1.0)  # initial condition

    drift = lambda y,t: 10      # define drift term
    diffusion = lambda y,t: sigma# define diffusion term
    noise = np.random.normal(loc=0.0,scale=1.0,size=length)*np.sqrt(dt) #define noise process

    # solve SDE using the Euler-Maruyama scheme
    for i in range(1,length):
        y[i] = y[i-1] + drift(y[i-1],i*dt)*dt + diffusion(y[i-1],i*dt)*noise[i]

    plt.plot(t,y)

plt.show()

# %%
import sys
sys.path.append("./source")

from stochastic_ode import *
import matplotlib.pyplot as plt

t, y = simulate_euler_maruyama(sigma=0.001)
plt.plot(t,y[:,0])

plt.show()

# %% [markdown]
# t, y = simulate_euler_maruyama(sigma=0.001)
# plt.clf()
# plt.figure(figsize=(20, 10))
# for species in range(7):
#     plt.subplot(4, 2, species + 1)
#     #plt.yscale('log')
#     plt.plot(t, y[:,species], 'r.')

# %%
t, y = simulate_euler_maruyama(sigma=0.09)
plt.clf()
plt.figure(figsize=(20, 10))
for species in range(7):
    plt.subplot(4, 2, species + 1)
    #plt.yscale('log')
    plt.plot(t, y[:,species], 'r.')
# Out:
# ./source/stochastic_ode.py:188: RuntimeWarning: overflow encountered in double_scalars
#   d_MPF = k3*cyclin*CDK - k2*MPF - kwee*MPF + k25*preMPF
# ./source/stochastic_ode.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   d_MPF = k3*cyclin*CDK - k2*MPF - kwee*MPF + k25*preMPF
# ./source/stochastic_ode.py:189: RuntimeWarning: overflow encountered in double_scalars
#   d_preMPF = -k2*preMPF + kwee*MPF - k25*preMPF
# ./source/stochastic_ode.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   d_preMPF = -k2*preMPF + kwee*MPF - k25*preMPF
# ./source/stochastic_ode.py:190: RuntimeWarning: overflow encountered in double_scalars
#   d_cdc25P = ka*MPF*(cdc25_total - cdc25P)/(Ka + cdc25_total - cdc25P) - kb*PPase*cdc25P/(Kb + cdc25P)
# ./source/stochastic_ode.py:191: RuntimeWarning: overflow encountered in double_scalars
#   d_wee1P = ke*MPF*(wee1_total - wee1P)/(Ke + wee1_total - wee1P) - kf*PPase*wee1P/(Kf + wee1P)
# ...

# %% [markdown]
# Pending. COPASI for stochastic ODE solver?

# %% [markdown]
# $$ \dot{x} = f(x, t, u, \alpha) $$
